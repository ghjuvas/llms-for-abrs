# %% [markdown]
# # Getting data for token classification task
# We tend to get data for token classification task. We have datasets on restaurants and automobiles that have to be processed. To train our model for token classification we must have sentences from the texts.
#
# Our datasets have specific markup that require predefined tokenization and labeling.

# %% [markdown]
# ## Imports

# %%
# !pip3 install stanza --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.5/802.5 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.9/240.9 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
import logging
from string import punctuation
from google.colab import drive
import stanza
import numpy as np
import pandas as pd

stanza.download('ru')

logging.basicConfig(level=logging.INFO)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# INFO:stanza:Downloading default packages for language: ru (Russian) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-ru/resolve/v1.5.0/models/default.zip:   0%|          | 0…
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.

# %%
PUNCTUATION = punctuation.replace('\'', '').replace('"', '')

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Getting data

# %%
train_restaurants_reviews = pd.read_csv('/content/drive/MyDrive/Summarization/restaurant data/train_split_reviews.txt', delimiter='\t', names=['text_id', 'text'])
train_automobiles_reviews = pd.read_csv('/content/drive/MyDrive/Summarization/automobile data/train_split_reviews.txt', delimiter='\t', names=['text_id', 'text'])

train_reviews = pd.concat([train_restaurants_reviews, train_automobiles_reviews])

train_restaurants_reviews.head()
# Out:
#    text_id                                               text
# 0    10231  Я несколько раз была в этом заведении,о кухне ...
# 1     6376  Впервые посетила это замечательное место! С пе...
# 2     7824  Праздновала в этом ресторане свой Др, праздник...
# 3    11825  После прогулки решили с подругой зайти-перекус...
# 4     2107  Случайно зашли в это заведение с друзьями. Сде...

# %%
print(len(train_reviews))
print(len(set(train_reviews['text_id'].values)))
# Out:
# 616
# 616

# %%
dev_restaurants_reviews = pd.read_csv('/content/drive/MyDrive/Summarization/restaurant data/dev_reviews.txt', delimiter='\t', names=['text_id', 'text'])
dev_automobiles_reviews = pd.read_csv('/content/drive/MyDrive/Summarization/automobile data/dev_reviews.txt', delimiter='\t', names=['text_id', 'text'])

dev_reviews = pd.concat([dev_restaurants_reviews, dev_automobiles_reviews])

len(dev_reviews)
# Out:
# 206

# %%
train_restaurants_aspects = pd.read_csv('/content/drive/MyDrive/Summarization/restaurant data/train_split_aspects.txt', delimiter='\t', names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment'])
train_automobiles_aspects = pd.read_csv('/content/drive/MyDrive/Summarization/automobile data/train_split_aspects.txt', delimiter='\t', names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment'])

train_aspects = pd.concat([train_restaurants_aspects, train_automobiles_aspects])

train_restaurants_aspects.head()
# Out:
#    text_id  category                   mention  start  end sentiment
# 0    30808     Whole                 ресторане     16   25   neutral
# 1    30808  Interior              первом этаже     43   55   neutral
# 2    30808     Whole     руководству ресторана    124  145  positive
# 3    30808   Service  обслуживающему персоналу    147  171  positive
# 4    30808   Service               сотрудникам    189  200  positive

# %%
dev_restaurants_aspects = pd.read_csv('/content/drive/MyDrive/Summarization/restaurant data/dev_aspects.txt', delimiter='\t', names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment'])
dev_automobiles_aspects = pd.read_csv('/content/drive/MyDrive/Summarization/automobile data/dev_aspects.txt', delimiter='\t', names=['text_id', 'category', 'mention', 'start', 'end', 'sentiment'])

dev_aspects = pd.concat([dev_restaurants_aspects, dev_automobiles_aspects])

len(dev_aspects)
# Out:
# 4794

# %%
# to divide into parts after processing
eval_restaurants_reviews = dev_restaurants_reviews[:50]
test_restaurants_reviews = dev_restaurants_reviews[50:]
eval_automobiles_reviews = dev_automobiles_reviews[:50]
test_automobiles_reviews = dev_automobiles_reviews[50:]

eval_reviews = pd.concat([eval_restaurants_reviews, eval_automobiles_reviews])
test_reviews = pd.concat([test_restaurants_reviews, test_automobiles_reviews])

# %% [markdown]
# ## Processing data

# %%
nlp = stanza.Pipeline('ru', processors='tokenize', verbose=False)

# %%
doc = nlp('Это первое предложение. А это второе предложение')

for sent in doc.sentences:
    print(sent.tokens[-1].text, sent.tokens[-1].end_char, sep='\t')
# Out:
# .	23
# предложение	48

# %%
BIO = ['B-ASPECT', 'I-ASPECT', 'O']
BIO_sent = ['B-POS', 'I-POS', 'B-NEG', 'I-NEG', 'B-NEUT', 'I-NEUT', 'O']

label2id = {label: i for i, label in enumerate(BIO)}
id2label = {i: label for i, label in enumerate(BIO)}
label2id_sent = {label: i for i, label in enumerate(BIO_sent)}
id2label_sent = {i: label for i, label in enumerate(BIO_sent)}

# %% [markdown]
# After `stanza` tokenization there are many sticked punctuation marks that often makes indentification of aspects in the tokenized text more difficult.

# %%
text = ',,,начинка"'
start_char = 13
end_char = 23

right_text = text.lstrip(PUNCTUATION)
start_char = start_char + (len(text) - len(right_text))

token_text = right_text.rstrip(PUNCTUATION)
end_char = end_char - (len(right_text) - len(token_text))

# %%
print(token_text)
print(start_char, end_char)
# Out:
# начинка"
# 16 23

# %% [markdown]
# There is another difficult: in the dataset there are cases of aspects overlapping. This problem can be solved in two ways:
#
#
# *   Keep only the aspects that have maximum spans
# *   Generate many variations of aspects markup that have smaller and larger spans of the text
#
#
# *Note: using second variant we can get additional data for training (variation of data augmentation)*

# %%
def get_data(reviews: pd.DataFrame, aspects: pd.DataFrame) -> tuple:
    '''
    Get tokens and labels to fine-tune models for AE as NER task.
    '''
    bad_labels = 0

    review_ids = []
    sentences = []
    data = []
    aspect_labels = []
    sentiment_labels = []

    logging.warning('Start getting data...')

    for rev_idx, rev in reviews.iterrows():
        # get text id and text
        text_id = int(rev['text_id'])
        text = rev['text']

        logging.warning('Text ID: %s' % text_id)

        # stanza processing to parse sentences
        doc = nlp(text)
        logging.warning('Processed by stanza...')

        # get needed mentions and aspects
        rev_aspects = aspects[aspects['text_id'] == text_id]

        mentions = rev_aspects['mention'].values.tolist()
        starts = rev_aspects['start'].values.tolist()
        ends = rev_aspects['end'].values.tolist()
        sentiment = rev_aspects['sentiment'].values.tolist()

        assert len(starts) == len(ends)

        # parse sentences
        logging.warning('Parse sentences...')
        for sent in doc.sentences:

            review_ids.append(text_id)  # text id that corresponds to sentence
            sentences.append(sent.text)

            sentence = []
            sentence_aspect_labels = []
            sentence_sentiment_labels = []

            # current state for multiple token aspects
            current_start = None
            current_end = 0
            current_id = None

            for token_idx, token in enumerate(sent.tokens):
                sentence.append(token.text)

                # save state of the token and indexes
                token_text = token.text
                start_char = token.start_char
                end_char = token.end_char

                # print(token_text, start_char, end_char)

                # remove punctuation from token string
                if token_text not in PUNCTUATION:
                    right_text = token_text.lstrip(PUNCTUATION)
                    start_char = start_char + (len(token_text) - len(right_text))

                    token_text = right_text.rstrip(PUNCTUATION)
                    end_char = end_char - (len(right_text) - len(token_text))

                # if after that string does not match start or start+end
                # it is outside label
                # print(token_text, start_char, end_char)

                # if we have multiple tokens in one aspect
                # if aspects start are enclosed then prevent new beginning
                if current_start:
                    # print('CURRENT START')
                    sentiment_value = sentiment[current_id]
                    sentence_aspect_labels.append(label2id.get('I-ASPECT', None))
                    if sentiment_value == 'positive':
                        sentence_sentiment_labels.append(label2id_sent.get('I-POS', None))
                    elif sentiment_value == 'negative':
                        sentence_sentiment_labels.append(label2id_sent.get('I-NEG', None))
                    elif sentiment_value == 'neutral' or sentiment_value == 'both':
                        sentence_sentiment_labels.append(label2id_sent.get('I-NEUT', None))

                    if end_char >= current_end:
                        # print('END OF INSIDE')
                        # print(token_idx, token.text, 'INSIDE')
                        # if it is the last token in the current aspect
                        # update state
                        current_start = None
                        current_end = 0
                        current_id = None

                elif start_char in starts:
                    # print('START')
                    
                    # starts may be not unique
                    dupl_start_idxs = [i for i, x in enumerate(starts) if x == start_char]
                    # get the largest span
                    if len(dupl_start_idxs) > 1:
                        local_end = 0
                        for idx in dupl_start_idxs:
                            new_end = ends[idx]
                            if new_end > current_end:
                                local_end = new_end
                                current_id = idx
                    else:
                        current_id = dupl_start_idxs[0]

                    if end_char < ends[current_id]:
                        # print('doesnt match', ends[current_id])
                        # print(token_idx, token.text, 'BEGIN')

                        current_start = starts[current_id]
                        current_end = ends[current_id]

                    sentence_aspect_labels.append(label2id.get('B-ASPECT', None))
                    sentiment_value = sentiment[current_id]
                    if sentiment_value == 'positive':
                        sentence_sentiment_labels.append(label2id_sent.get('B-POS', None))
                    elif sentiment_value == 'negative':
                        sentence_sentiment_labels.append(label2id_sent.get('B-NEG', None))
                    elif sentiment_value == 'neutral' or sentiment_value == 'both':
                        sentence_sentiment_labels.append(label2id_sent.get('B-NEUT', None))

                else:  # other cases
                    # print('OTHER')
                    sentence_aspect_labels.append(label2id.get('O', None))
                    sentence_sentiment_labels.append(label2id_sent.get('O', None))
                    # print(token_idx, token.text, 'OUTSIDE')

            if len(sentence_aspect_labels) != len(sentence) or\
            len(sentence_sentiment_labels) != len(sentence):
                print('MISMATCHED LABELING')
                print(sentence_aspect_labels)
                print('length of sentence aspect labels', len(sentence_aspect_labels))
                print('length of sentence sentiment labels', len(sentence_sentiment_labels))
                print(sentence)
                print('length of sentence', len(sentence))
                print(sent.text)

                bad_labels += 1

            data.append(sentence)
            aspect_labels.append(sentence_aspect_labels)
            sentiment_labels.append(sentence_sentiment_labels)

    logging.warning('Bad labels %d' % bad_labels)

    return review_ids, sentences, data, aspect_labels, sentiment_labels

# %%
train_aspects[train_aspects['text_id'] == 922226]  # overlapping aspects
# Out:
#       text_id      category                      mention  start  end sentiment
# 1250   922226         Whole                   автомобиле     43   53   neutral
# 1251   922226       Comfort                        салон     74   79  negative
# 1252   922226       Comfort                       тесный    100  106  negative
# 1253   922226       Comfort                    неудобный    109  118  negative
# 1254   922226         Whole                это не машина    143  156  negative
# 1255   922226       Comfort                     Багажник    158  166  negative
# 1256   922226       Comfort  не отличается просторностью    172  199  negative
# 1257   922226       Comfort                просторностью    186  199  positive
# 1258   922226       Comfort                      сверчки    220  227  negative
# 1259   922226       Comfort                       салону    237  243  negative
# 1260   922226       Comfort          упирается в коленки    294  313  negative
# 1261   922226       Comfort                       модели    375  381  negative
# 1262   922226       Comfort                 устает спина    413  425  negative
# 1263   922226   Reliability                     Качество    427  435  negative
# 1264   922226   Reliability                    запчастей    436  445  negative
# 1265   922226   Reliability                       сборки    448  454  negative
# 1266   922226         Whole                       машины    499  505  negative
# 1267   922226         Costs                         цена    540  544  positive
# 1268   922226         Whole                       модель    670  676  negative
# 1269   922226    Appearance                       Дизайн    694  700  negative
# 1270   922226       Comfort                    неудобный    753  762  negative
# 1271   922226       Comfort                        салон    763  768  negative
# 1272   922226  Driveability                 Проходимость    770  782  negative
# 1273   922226   Reliability                     Качество    791  799  negative
# 1274   922226   Reliability                       сборки    800  806  negative

# %%
text = train_reviews[train_reviews['text_id'] == 1234566]['text'].values[0]

text
# Out:
# 'Наша белочка с нами уже 6 лет, менять пока не собираемся. Когда встал вопрос о том, какую машину можно купить в пределах 6000$, чтобы недорогая в обслуживании и экономичная в бензине, то выбар пал на наш белый Sens. Выбрали именно белый цвет-смотрится очень красиво. Ездили на нем постоянно, ремонтировали редко-настоящаяя лошадка. Из плюсов -в салоне достаточно хороший пластик -удобные сидения -прошла хороший краш тест (показала себя молодцом) -недорогая в обслуживании Из минусов: -движок 1.3 слабоват конечно( пробовала недавно ездить на Ланосе-сразу почувствовала разницу) В общем машинкой очень довольны, но время идет и хочется что-нибудь поновее, хотя и продавать жалко. '

# %%
train_aspects[train_aspects['text_id'] == 1234566]
# Out:
#       text_id      category              mention  start  end sentiment
# 3499  1234566         Whole               машину     90   96  positive
# 3500  1234566         Costs            недорогая    134  143  positive
# 3501  1234566         Costs         обслуживании    146  158  positive
# 3502  1234566         Costs          экономичная    161  172  positive
# 3503  1234566         Costs              бензине    175  182  positive
# 3504  1234566         Whole                 Sens    210  214  positive
# 3505  1234566    Appearance            смотрится    242  251  positive
# 3506  1234566    Appearance              красиво    258  265  positive
# 3507  1234566   Reliability  ремонтировали редко    292  311  positive
# 3508  1234566       Comfort               салоне    345  351  positive
# 3509  1234566   Reliability              пластик    371  378  positive
# 3510  1234566       Comfort              удобные    380  387  positive
# 3511  1234566       Comfort              сидения    388  395  positive
# 3512  1234566        Safety            краш тест    412  421  positive
# 3513  1234566         Costs            недорогая    448  457  positive
# 3514  1234566         Costs         обслуживании    460  472  positive
# 3515  1234566  Driveability           движок 1.3    486  496  negative
# 3516  1234566  Driveability               Ланосе    543  549  positive
# 3517  1234566         Whole             машинкой    587  595   neutral

# %%
doc = nlp(text)

for sent in doc.sentences:
    for token in sent.tokens:
        print(token.text, token.start_char, token.end_char)
# Out:
# Наша 0 4
# белочка 5 12
# с 13 14
# нами 15 19
# уже 20 23
# 6 24 25
# лет 26 29
# , 29 30
# менять 31 37
# пока 38 42
# не 43 45
# собираемся 46 56
# . 56 57
# Когда 58 63
# встал 64 69
# вопрос 70 76
# о 77 78
# том 79 82
# , 82 83
# какую 84 89
# машину 90 96
# можно 97 102
# купить 103 109
# в 110 111
# пределах 112 120
# 6000 121 125
# $ 125 126
# , 126 127
# чтобы 128 133
# недорогая 134 143
# в 144 145
# обслуживании 146 158
# и 159 160
# экономичная 161 172
# в 173 174
# бензине 175 182
# , 182 183
# то 184 186
# выбар 187 192
# пал 193 196
# на 197 199
# наш 200 203
# белый 204 209
# Sens 210 214
# . 214 215
# Выбрали 216 223
# именно 224 230
# белый 231 236
# цвет 237 241
# - 241 242
# смотрится 242 251
# очень 252 257
# красиво 258 265
# . 265 266
# Ездили 267 273
# на 274 276
# нем 277 280
# постоянно 281 290
# , 290 291
# ремонтировали 292 305
# редко-настоящаяя 306 322
# лошадка 323 330
# . 330 331
# Из 332 334
# плюсов 335 341
# - 342 343
# в 343 344
# салоне 345 351
# достаточно 352 362
# хороший 363 370
# пластик 371 378
# - 379 380
# удобные 380 387
# сидения 388 395
# - 396 397
# прошла 397 403
# хороший 404 411
# краш 412 416
# тест 417 421
# ( 422 423
# показала 423 431
# себя 432 436
# молодцом 437 445
# ) 445 446
# - 447 448
# недорогая 448 457
# в 458 459
# обслуживании 460 472
# Из 473 475
# минусов 476 483
# : 483 484
# - 485 486
# движок 486 492
# 1.3 493 496
# слабоват 497 505
# конечно 506 513
# ( 513 514
# пробовала 515 524
# недавно 525 532
# ездить 533 539
# на 540 542
# Ланосе 543 549
# - 549 550
# сразу 550 555
# почувствовала 556 569
# разницу 570 577
# ) 577 578
# В 579 580
# общем 581 586
# машинкой 587 595
# очень 596 601
# довольны 602 610
# , 610 611
# но 612 614
# время 615 620
# идет 621 625
# и 626 627
# хочется 628 635
# что-нибудь 636 646
# поновее 647 654
# , 654 655
# хотя 656 660
# и 661 662
# продавать 663 672
# жалко 673 678
# . 678 679

# %%
review_ids, sentences, data, aspect_labels, sentiment_labels = get_data(train_reviews[train_reviews['text_id'] == 1234566], train_aspects)
# Out:
# WARNING:root:Start getting data...
# WARNING:root:Text ID: 1234566
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Bad labels 0

# %%
review_ids
# Out:
# [1234566, 1234566, 1234566, 1234566, 1234566, 1234566]

# %%
print(data[4])
print(aspect_labels[4])
print(sentiment_labels[4])
# Out:
# ['Из', 'плюсов', '-', 'в', 'салоне', 'достаточно', 'хороший', 'пластик', '-', 'удобные', 'сидения', '-', 'прошла', 'хороший', 'краш', 'тест', '(', 'показала', 'себя', 'молодцом', ')', '-', 'недорогая', 'в', 'обслуживании', 'Из', 'минусов', ':', '-', 'движок', '1.3', 'слабоват', 'конечно', '(', 'пробовала', 'недавно', 'ездить', 'на', 'Ланосе', '-', 'сразу', 'почувствовала', 'разницу', ')']
# [2, 2, 2, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2, 0, 1, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2]
# [6, 6, 6, 6, 0, 6, 6, 0, 6, 0, 0, 6, 6, 6, 0, 1, 6, 6, 6, 6, 6, 6, 0, 6, 0, 6, 6, 6, 6, 2, 3, 6, 6, 6, 6, 6, 6, 6, 0, 6, 6, 6, 6, 6]

# %% [markdown]
# Full data:

# %%
train_review_ids, train_sentences, train_data, train_aspect_labels, train_sentiment_labels = get_data(train_reviews, train_aspects)
# Out:
# WARNING:root:Start getting data...
# WARNING:root:Text ID: 10231
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6376
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7824
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11825
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2107
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6366
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34710
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7890
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37505
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33952
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11058
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19439
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37573
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11155
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33524
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16676
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10239
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 29395
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24214
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9216
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16322
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38045
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 31004
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5037
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3705
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14865
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33520
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3552
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27841
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13623
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 4063
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24916
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18983
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27169
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 39042
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36079
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11116
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2168
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38077
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3762
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1200
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36483
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3875
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7718
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35863
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35904
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33838
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5831
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2606
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7779
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1368
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2006
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9076
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2345
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9662
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 4308
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 22975
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33825
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35790
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9776
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24713
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20021
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36948
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1749
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13186
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 25709
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14177
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1052
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9036
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11532
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34607
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33082
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33976
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 30744
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14568
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37391
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37473
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 25960
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 26284
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3385
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15159
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1032
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20417
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15655
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19467
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8411
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6962
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5155
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28585
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2747
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20862
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1434
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1511
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 280
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27375
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13748
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24132
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8589
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 23369
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6710
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34334
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12943
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2468
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 31071
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3647
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33798
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12880
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7737
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18430
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2013
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 21059
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28612
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28745
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38972
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36589
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 4887
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12118
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33693
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27925
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38772
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7154
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20861
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1308
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 30148
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37631
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 17572
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 26887
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11770
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20086
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 343
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16137
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5211
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 26330
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34889
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12863
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12366
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19383
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2203
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32859
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15363
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6040
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7053
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8584
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12203
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28083
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10778
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5077
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 31963
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33912
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37819
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1563
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1269
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2692
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6564
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34761
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27620
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37036
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35501
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34045
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3152
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9721
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33252
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5648
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14190
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 17398
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 21716
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 22386
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35085
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 25753
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33405
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24501
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37516
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8012
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10985
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15423
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 30201
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32442
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18253
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7193
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12678
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 26152
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10825
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2495
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33538
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10354
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34232
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19746
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16378
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1427
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3906
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34282
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18148
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11793
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6155
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35867
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3480
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 29298
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18756
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 29321
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28275
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36407
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19817
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3231
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11267
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37070
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20784
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27629
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36049
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 17009
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19027
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10645
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35325
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32721
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37220
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36359
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5928
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32513
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16568
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 17475
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33043
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2965
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27539
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8996
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27569
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38299
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12467
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13790
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19111
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 622
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9230
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37784
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35635
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1105
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37364
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33665
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2364
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 17999
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8555
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10625
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 30808
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36205
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24578
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15335
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36926
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9955
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 719
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7603
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 23858
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35620
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10847
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36725
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8757
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16955
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32744
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7417
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 225
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9837
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32584
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36576
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3749
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 918
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5974
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24275
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 25861
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 24217
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32840
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27040
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33816
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38031
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36085
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 797
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36017
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37975
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15567
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37428
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16647
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1666
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 25507
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7079
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36274
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32995
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13835
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33897
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13252
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 803
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3452
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2073
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38371
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10099
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 23878
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5493
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10663
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16761
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3202
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8759
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16630
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33591
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 29350
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18003
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35486
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28112
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7011
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38196
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1276288
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 887900
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1211024
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1158398
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 894387
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 773254
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1202194
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 120188
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1165925
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 120575
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 861371
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 949524
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 931089
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 846173
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 839910
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 85486
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 850619
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 697844
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 95081
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1016743
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 664869
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1391287
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 780645
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1183119
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1153536
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1276142
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1025540
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1305169
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 639044
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 677337
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 78082
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 677377
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 652548
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 855017
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 984595
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 114173
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 115279
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 791282
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 915368
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 978655
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 624598
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 90104
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 123024
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 139268
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 808345
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 99123
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 826386
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1152398
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 760841
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 985905
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 718457
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 95863
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1282204
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 695706
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 978359
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 821064
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 821296
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1185105
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 85818
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1214487
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12038
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 930662
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 741652
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 802306
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 131639
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1301529
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 932082
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 831912
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 101530
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 118969
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 828979
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 770644
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 974849
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 667543
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 829548
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 83423
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 722913
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 99586
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 92403
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 739381
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 96424
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 67092
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1292767
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 765882
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1191263
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 898865
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 815806
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 142609
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 927524
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1287771
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 646161
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 92772
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 676765
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 89781
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 948087
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 95907
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1290276
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14082
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 823671
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1214432
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1195679
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 896840
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1234566
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 849573
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 834306
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 838620
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 727165
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 82033
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1257707
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1019337
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 717542
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 921659
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 755902
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 82707
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 757439
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1178575
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 628908
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 712173
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 991418
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 814536
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 813513
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 831122
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 811605
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1271094
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1194883
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 935099
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 793214
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 99646
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 845465
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 859733
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 989680
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1168520
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 815983
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 793200
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 783992
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1390545
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 673150
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 804338
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 679603
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 815639
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 83019
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 650960
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1159982
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 965147
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 75190
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1278090
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1311977
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1211602
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1207277
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 691746
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 928860
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 829795
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 860983
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1395346
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 82386
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 737219
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 791490
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1265915
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 74896
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 853950
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 699330
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1276722
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 644023
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 865964
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 654197
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 896369
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 92065
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 836062
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 998439
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1316547
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 935239
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 958350
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 950513
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 976318
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1286033
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 731743
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1168394
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 821905
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 92724
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 875501
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 83504
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 70249
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 716317
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 986055
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 862318
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 719807
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1016845
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 79209
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 763257
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7490
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 930605
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1163349
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 646130
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 850467
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 82397
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 762510
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1245394
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1195540
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 849580
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 806487
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 125497
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 891175
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 87369
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 954380
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 777478
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1214349
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 680864
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1193893
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 636263
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 829262
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 769481
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 798465
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 963075
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 760819
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1281554
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 892256
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1019301
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1270346
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 931815
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 894893
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 814743
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 940941
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1313822
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 861403
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 653826
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 623093
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1257700
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 790152
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 624388
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1178507
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 121992
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1244256
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 808842
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 653022
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 846454
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 686648
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 653170
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 81570
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 779297
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1214423
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1327649
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 864226
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 816831
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1199619
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 696941
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 769431
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 853744
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 877880
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 928724
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 874274
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 909461
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1216432
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 955597
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 772524
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 925522
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 73734
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 876954
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 74849
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 772650
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 835621
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 935992
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 707739
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 923331
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 780885
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 969550
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 721695
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 691987
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12771
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 116911
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 679097
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 71383
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 837419
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 878327
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 624755
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 874949
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 979507
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1198989
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 613332
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1197367
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 976231
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 882893
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1184249
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 744761
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 831490
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 846537
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 94518
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 702105
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1327355
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1168009
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1201197
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 654464
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 807915
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7429
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 766241
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 696261
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1298173
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1275887
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1302573
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 622400
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 850057
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 643765
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 922226
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 724602
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1253369
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1395536
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 614609
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 94516
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1198663
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 899854
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 85394
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 780223
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7492
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1178840
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Bad labels 0

# %%
len(train_data)
# Out:
# 6771

# %%
dev_review_ids, dev_sentences, dev_data, dev_aspect_labels, dev_sentiment_labels = get_data(dev_reviews, dev_aspects)
# Out:
# WARNING:root:Start getting data...
# WARNING:root:Text ID: 36381
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16274
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7982
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36512
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13823
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33720
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 7821
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36321
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34307
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34402
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 21856
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11421
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11355
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13912
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 35613
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 785
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34196
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18372
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6668
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 31778
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 4106
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9878
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38344
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32926
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38013
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12372
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38950
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9289
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 21574
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 26022
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12341
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13225
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3976
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2616
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16714
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34228
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 27816
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36781
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36166
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 3236
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 15758
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8663
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19503
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19265
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5324
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 8324
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14539
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38180
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1289
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 13100
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34956
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12591
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32367
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 20397
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 21399
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11388
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 19677
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18220
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 2089
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18518
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1515
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32771
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32040
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33598
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 9870
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28258
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 22015
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 22970
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12270
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37252
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 16151
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33621
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6880
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1751
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 38835
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32856
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36402
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12814
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11102
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32206
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 34575
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 33622
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 14031
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 29383
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 37611
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 22527
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 28710
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 32692
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 30368
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 11027
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 36126
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 18780
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 354
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10942
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 10798
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1878
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 31140
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 5441
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 12131
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 4658
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1154869
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 71849
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 663076
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 879515
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 131065
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 951633
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 90041
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 913934
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 767794
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 614553
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 931917
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 665128
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 851323
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1013693
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1138968
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1015576
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 604173
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 648467
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 879427
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 681350
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 661298
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 839692
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 687981
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 991047
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1175531
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 860494
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 625080
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 129782
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 735741
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 904170
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1234788
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 627933
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1285021
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 926132
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 822332
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1215478
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 907568
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 815242
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 840018
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 902907
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1189503
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 954729
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 856586
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 803355
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 900419
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 769974
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 625292
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 940972
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 903701
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 795309
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 92845
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 942871
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 778991
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 669020
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 6313
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 784524
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 903454
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1279421
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 758532
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 674627
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 949090
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 646519
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 976185
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 785664
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 98239
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1013861
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 86301
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1312535
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 726018
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 680534
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 70834
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 785910
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1159153
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 945428
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 872361
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1144344
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 731925
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 924616
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 969268
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 882114
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 126424
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 949009
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 941330
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 896577
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 735328
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 953573
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 919921
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 798263
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 708642
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1242760
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 926204
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 66373
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 719824
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1192669
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 869059
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 128483
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1291257
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 679693
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 762712
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 119273
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1149868
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 1017158
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 719714
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 929314
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Text ID: 941685
# WARNING:root:Processed by stanza...
# WARNING:root:Parse sentences...
# WARNING:root:Bad labels 0

# %%
len(dev_data)
# Out:
# 2237

# %% [markdown]
# ## Saving data

# %% [markdown]
# ### Full data

# %%
train_max_dataset = pd.DataFrame({
    'review_id': train_review_ids,
    'sentence_text': train_sentences,
    'sentence_tokens': train_data,
    'aspect_labels': train_aspect_labels,
    'sentiment_labels': train_sentiment_labels
})

train_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/train_max_ner.tsv', index=False, sep='\t')

# %%
dev_max_dataset = pd.DataFrame({
    'review_id': dev_review_ids,
    'sentence_text': dev_sentences,
    'sentence_tokens': dev_data,
    'aspect_labels': dev_aspect_labels,
    'sentiment_labels': dev_sentiment_labels
})

# %%
eval_max_dataset = dev_max_dataset[dev_max_dataset['review_id'].isin(eval_reviews['text_id'].values.tolist())]
eval_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/eval_max_ner.tsv', index=False, sep='\t')

eval_max_dataset.head()
# Out:
#    review_id                                      sentence_text  \
# 0      36381                                           Красиво.
# 1      36381                                            Вкусно.
# 2      36381                          Обслуживание "на уровне".
# 3      36381  Вот на этот "уровень" оно и ориентированно, не...
# 4      36381  Ресторан создавал впечатление пустого, только ...
#
#                                      sentence_tokens  \
# 0                                       [Красиво, .]
# 1                                        [Вкусно, .]
# 2                [Обслуживание, ", на, уровне, ", .]
# 3  [Вот, на, этот, ", уровень, ", оно, и, ориенти...
# 4  [Ресторан, создавал, впечатление, пустого, ,, ...
#
#                                        aspect_labels  \
# 0                                             [2, 2]
# 1                                             [0, 2]
# 2                                 [0, 2, 2, 2, 2, 2]
# 3  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
# 4               [0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#
#                                     sentiment_labels
# 0                                             [6, 6]
# 1                                             [0, 6]
# 2                                 [0, 6, 6, 6, 6, 6]
# 3  [6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# 4               [4, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6]

# %%
test_max_dataset = dev_max_dataset[dev_max_dataset['review_id'].isin(test_reviews['text_id'].values.tolist())]
test_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/test_max_ner.tsv', index=False, sep='\t')

test_max_dataset.head()
# Out:
#      review_id                                      sentence_text  \
# 559      13100  решили этот день рождения отметить семьей-я,же...
# 560      13100  За пару дней заказал столик,что оказалось весь...
# 561      13100  При входе улыбчивая девушка хостесс встретила ...
# 562      13100  Обслуживал молодой человек Антон.При выборе бл...
# 563      13100  На десерт жена взяла классический Наполеон,про...
#
#                                        sentence_tokens  \
# 559  [решили, этот, день, рождения, отметить, семье...
# 560  [За, пару, дней, заказал, столик, ,, что, оказ...
# 561  [При, входе, улыбчивая, девушка, хостесс, встр...
# 562  [Обслуживал, молодой, человек, Антон., При, вы...
# 563  [На, десерт, жена, взяла, классический, Наполе...
#
#                                          aspect_labels  \
# 559                     [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# 560  [2, 2, 2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
# 561            [2, 2, 2, 0, 1, 0, 2, 0, 1, 1, 2, 2, 2]
# 562  [0, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
# 563  [2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, ...
#
#                                       sentiment_labels
# 559                     [6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# 560  [6, 6, 6, 4, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# 561            [6, 6, 6, 0, 1, 0, 6, 0, 1, 1, 6, 6, 6]
# 562  [4, 4, 5, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# 563  [6, 0, 6, 6, 6, 0, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...

# %% [markdown]
# ### Restaurants

# %%
train_restaurants_max_dataset = train_max_dataset[train_max_dataset['review_id'].isin(train_restaurants_reviews['text_id'].values.tolist())]

train_restaurants_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/train_restaurants_max_ner.tsv', index=False, sep='\t')

# %%
eval_restaurants_max_dataset = dev_max_dataset[dev_max_dataset['review_id'].isin(eval_restaurants_reviews['text_id'].values.tolist())]

eval_restaurants_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/eval_restaurants_max_ner.tsv', index=False, sep='\t')

# %%
test_restaurants_max_dataset = dev_max_dataset[dev_max_dataset['review_id'].isin(test_restaurants_reviews['text_id'].values.tolist())]

test_restaurants_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/test_restaurants_max_ner.tsv', index=False, sep='\t')

# %% [markdown]
# ### Automobiles

# %%
train_automobiles_max_dataset = train_max_dataset[train_max_dataset['review_id'].isin(train_automobiles_reviews['text_id'].values.tolist())]

train_automobiles_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/train_automobiles_max_ner.tsv', index=False, sep='\t')

# %%
eval_automobiles_max_dataset = dev_max_dataset[dev_max_dataset['review_id'].isin(eval_automobiles_reviews['text_id'].values.tolist())]

eval_automobiles_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/eval_automobiles_max_ner.tsv', index=False, sep='\t')

# %%
test_automobiles_max_dataset = dev_max_dataset[dev_max_dataset['review_id'].isin(test_automobiles_reviews['text_id'].values.tolist())]

test_automobiles_max_dataset.to_csv('/content/drive/MyDrive/Summarization/aspects/test_automobiles_max_ner.tsv', index=False, sep='\t')
